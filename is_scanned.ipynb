# %%
from core import *
import os

# %%
import os
color_range_scanned = []
directory = '/home/mmed/Documents/projects/bill_reader/data'
for filename in os.listdir(directory):
    cur_dir = os.path.join(directory, filename)
    image = get_image(cur_dir)
    color_range_scanned.append(len(np.unique(image.reshape(-1, image.shape[2]), axis=0)))
s = pd.Series(data= color_range_scanned)
s.agg(['min',"max","mean"])
# Out:
# min      10.00000
# max     251.00000
# mean     25.03125
# dtype: float64

# %%
color_range_scanned = []
directory = '/home/mmed/Wallpapers'
for filename in os.listdir(directory):
    cur_dir = os.path.join(directory, filename)
    image = get_image(cur_dir)
    color_range_scanned.append(len(np.unique(image.reshape(-1, image.shape[2]), axis=0)))
s = pd.Series(data= color_range_scanned)
s.agg(['min',"max","mean"])
# Out:
# min          9.000000
# max     715188.000000
# mean    165793.611111
# dtype: float64

# %%
file1 = '/home/mmed/Documents/projects/bill_reader/swap_png/notscanned.png'
file2 = '/home/mmed/Documents/projects/bill_reader/data/applebees_8267120140431.pdf'

image = get_image(file1)
plt.imshow(image)
plt.show()

# %%
image = get_final_image(file1)
plt.imshow(image)
plt.show()

# %%
image = get_final_image(file2)
plt.imshow(image)
plt.show()
